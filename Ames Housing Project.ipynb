# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-Statement:" data-toc-modified-id="Problem-Statement:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Problem Statement:</a></span></li><li><span><a href="#What-are-the-most-important-factors-that-determine-house-prices---The-case-of-Ames,-Iowa." data-toc-modified-id="What-are-the-most-important-factors-that-determine-house-prices---The-case-of-Ames,-Iowa.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>What are the most important factors that determine house prices - The case of Ames, Iowa.</a></span><ul class="toc-item"><li><span><a href="#Importing-the-libraries" data-toc-modified-id="Importing-the-libraries-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Importing the libraries</a></span></li><li><span><a href="#Reading-the-Dataset" data-toc-modified-id="Reading-the-Dataset-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Reading the Dataset</a></span></li><li><span><a href="#Cleaning-Data" data-toc-modified-id="Cleaning-Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Cleaning Data</a></span><ul class="toc-item"><li><span><a href="#Looking-at-the-Data" data-toc-modified-id="Looking-at-the-Data-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Looking at the Data</a></span></li><li><span><a href="#Finding-the-missing-values" data-toc-modified-id="Finding-the-missing-values-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Finding the missing values</a></span></li><li><span><a href="#Comparing-the-two-datasets" data-toc-modified-id="Comparing-the-two-datasets-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Comparing the two datasets</a></span></li><li><span><a href="#Drop-the-irrelevant-columns-from-both-datasets" data-toc-modified-id="Drop-the-irrelevant-columns-from-both-datasets-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Drop the irrelevant columns from both datasets</a></span></li><li><span><a href="#Looking-at-the-Categorical-Data---Filling-the-NA-category-with-'Not'" data-toc-modified-id="Looking-at-the-Categorical-Data---Filling-the-NA-category-with-'Not'-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Looking at the Categorical Data - Filling the NA category with 'Not'</a></span></li><li><span><a href="#Making-a-dictionary-for-the-ordinal-variables" data-toc-modified-id="Making-a-dictionary-for-the-ordinal-variables-2.3.6"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span>Making a dictionary for the ordinal variables</a></span></li><li><span><a href="#Applying-the-dictionary-to-both-the-dataframes" data-toc-modified-id="Applying-the-dictionary-to-both-the-dataframes-2.3.7"><span class="toc-item-num">2.3.7&nbsp;&nbsp;</span>Applying the dictionary to both the dataframes</a></span></li></ul></li><li><span><a href="#Combining-both-dataframes-to-create-dummy-variables-for-both" data-toc-modified-id="Combining-both-dataframes-to-create-dummy-variables-for-both-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Combining both dataframes to create dummy variables for both</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Some-Feature-Engineering" data-toc-modified-id="Some-Feature-Engineering-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Some Feature Engineering</a></span></li><li><span><a href="#Visualizations" data-toc-modified-id="Visualizations-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Visualizations</a></span></li></ul></li></ul></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Baseline-Model" data-toc-modified-id="Baseline-Model-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Baseline Model</a></span></li><li><span><a href="#Linear-Regression-Model" data-toc-modified-id="Linear-Regression-Model-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Linear Regression Model</a></span><ul class="toc-item"><li><span><a href="#Model-1---Using-the-entire-dataset" data-toc-modified-id="Model-1---Using-the-entire-dataset-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Model 1 - Using the entire dataset</a></span></li><li><span><a href="#Finding-RMSE-Scores" data-toc-modified-id="Finding-RMSE-Scores-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Finding RMSE Scores</a></span></li></ul></li><li><span><a href="#Running-the-model-on-the-Validation-dataset" data-toc-modified-id="Running-the-model-on-the-Validation-dataset-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Running the model on the Validation dataset</a></span><ul class="toc-item"><li><span><a href="#Submitting-to-Kaggle" data-toc-modified-id="Submitting-to-Kaggle-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Submitting to Kaggle</a></span></li></ul></li></ul></li><li><span><a href="#Model-2---Trying-different-features" data-toc-modified-id="Model-2---Trying-different-features-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Model 2 - Trying different features</a></span></li><li><span><a href="#Model-3---Looking-at-the-variance-in-price-explained-by-the-two-most-correlated-variables---Total-Area-and-Overall-Quality-of-the-house" data-toc-modified-id="Model-3---Looking-at-the-variance-in-price-explained-by-the-two-most-correlated-variables---Total-Area-and-Overall-Quality-of-the-house-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Model 3 - Looking at the variance in price explained by the two most correlated variables - Total Area and Overall Quality of the house</a></span></li><li><span><a href="#Lasso-Regression" data-toc-modified-id="Lasso-Regression-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Lasso Regression</a></span><ul class="toc-item"><li><span><a href="#Trying-OLS-using-statsmodels" data-toc-modified-id="Trying-OLS-using-statsmodels-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Trying OLS using statsmodels</a></span></li></ul></li><li><span><a href="#Ridge-Regression-Model" data-toc-modified-id="Ridge-Regression-Model-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Ridge Regression Model</a></span></li><li><span><a href="#Choosing-my-model-and-plotting-the-residuals" data-toc-modified-id="Choosing-my-model-and-plotting-the-residuals-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Choosing my model and plotting the residuals</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#I-chose-the-Linear-Regression-model-because-the-Lasso-or-the-Ridge-regressions-did-not-significantly-improve-my-model.-I-wanted-to-have-all-the-features-in-my-model-to-see-how-they-affect-the-price-of-the-house." data-toc-modified-id="I-chose-the-Linear-Regression-model-because-the-Lasso-or-the-Ridge-regressions-did-not-significantly-improve-my-model.-I-wanted-to-have-all-the-features-in-my-model-to-see-how-they-affect-the-price-of-the-house.-8.0.1"><span class="toc-item-num">8.0.1&nbsp;&nbsp;</span>I chose the Linear Regression model because the Lasso or the Ridge regressions did not significantly improve my model. I wanted to have all the features in my model to see how they affect the price of the house.</a></span></li></ul></li><li><span><a href="#Visualization-of-my-chosen-model" data-toc-modified-id="Visualization-of-my-chosen-model-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Visualization of my chosen model</a></span></li></ul></li><li><span><a href="#Conclusions" data-toc-modified-id="Conclusions-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Conclusions</a></span></li></ul></div>

# %% [markdown]
# # Problem Statement:
#
# # What are the most important factors that determine house prices - The case of Ames, Iowa.
#
# The Ames Dataset is a dataset of all features of houses sold in Ames, IA between 2006-10. The purpose of this project is to determine the factors that lead to higher sale prices and what makes a house sell. I am a researcher hired by a professor who is writing a paper on what makes housing prices go up. This is an important question for homeowners as well as financial institutions who predict house prices based on data.

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import patsy

from sklearn.linear_model    import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing   import StandardScaler, PolynomialFeatures
from sklearn.dummy           import DummyRegressor
from sklearn.metrics         import mean_squared_error

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

RANDOM_STATE = 123

# %% [markdown]
# ## Reading the Dataset

# %%
housing = pd.read_csv("./datasets/train.csv")
housing.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# ...

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Looking at the Data

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
# Id                 2051 non-null int64
# PID                2051 non-null int64
# MS SubClass        2051 non-null int64
# MS Zoning          2051 non-null object
# Lot Frontage       1721 non-null float64
# Lot Area           2051 non-null int64
# Street             2051 non-null object
# Alley              140 non-null object
# Lot Shape          2051 non-null object
# Land Contour       2051 non-null object
# Utilities          2051 non-null object
# Lot Config         2051 non-null object
# Land Slope         2051 non-null object
# Neighborhood       2051 non-null object
# Condition 1        2051 non-null object
# Condition 2        2051 non-null object
# Bldg Type          2051 non-null object
# House Style        2051 non-null object
# Overall Qual       2051 non-null int64
# Overall Cond       2051 non-null int64
# Year Built         2051 non-null int64
# ...

# %%
housing.isnull().sum().sum()
# Out:
# 9822

# %%
housing.shape
# Out:
# (2051, 81)

# %%
housing.describe().T
# Out:
#                   count          mean           std          min          25%  \
# Id               2051.0  1.474034e+03  8.439808e+02          1.0        753.5
# PID              2051.0  7.135900e+08  1.886918e+08  526301100.0  528458140.0
# MS SubClass      2051.0  5.700878e+01  4.282422e+01         20.0         20.0
# Lot Frontage     1721.0  6.905520e+01  2.326065e+01         21.0         58.0
# Lot Area         2051.0  1.006521e+04  6.742489e+03       1300.0       7500.0
# Overall Qual     2051.0  6.112140e+00  1.426271e+00          1.0          5.0
# Overall Cond     2051.0  5.562165e+00  1.104497e+00          1.0          5.0
# Year Built       2051.0  1.971709e+03  3.017789e+01       1872.0       1953.5
# Year Remod/Add   2051.0  1.984190e+03  2.103625e+01       1950.0       1964.5
# Mas Vnr Area     2029.0  9.969591e+01  1.749631e+02          0.0          0.0
# BsmtFin SF 1     2050.0  4.423005e+02  4.612041e+02          0.0          0.0
# ...

# %%
housing["MS SubClass"].value_counts()
# Out:
# 20     770
# 60     394
# 50     198
# 120    132
# 30     101
# 70      90
# 160     88
# 80      86
# 90      75
# 190     46
# 85      28
# 75      16
# 45      11
# 180     11
# 40       4
# 150      1
# Name: MS SubClass, dtype: int64

# %%
housing["MS Zoning"].value_counts()
# Out:
# RL         1598
# RM          316
# FV          101
# C (all)      19
# RH           14
# A (agr)       2
# I (all)       1
# Name: MS Zoning, dtype: int64

# %%
housing[["Year Built", "Year Remod/Add", "Mo Sold","Yr Sold"]].describe()
# Out:
#         Year Built  Year Remod/Add      Mo Sold      Yr Sold
# count  2051.000000     2051.000000  2051.000000  2051.000000
# mean   1971.708922     1984.190151     6.219893  2007.775719
# std      30.177889       21.036250     2.744736     1.312014
# min    1872.000000     1950.000000     1.000000  2006.000000
# 25%    1953.500000     1964.500000     4.000000  2007.000000
# 50%    1974.000000     1993.000000     6.000000  2008.000000
# 75%    2001.000000     2004.000000     8.000000  2009.000000
# max    2010.000000     2010.000000    12.000000  2010.000000

# %% [markdown]
# ### Finding the missing values

# %%
#Checking the null values
plt.figure(figsize =(16,9))
sns.heatmap(housing.isnull(), cbar=False)

# %% [markdown]
# ### Comparing the two datasets

# %%
valid = pd.read_csv("./datasets/test.csv")
valid.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       Reg          Lvl  ...          0            0         0     NaN
# 4   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# ...

# %%
# Converting the MS SubClass to a string since it is a nominal variable
housing["MS SubClass"] = housing["MS SubClass"].astype(str)
valid["MS SubClass"] = valid["MS SubClass"].astype(str)

# %%
# Calculating the age of the house
housing["age"] = housing["Yr Sold"] - housing["Year Built"]
housing["age"].describe()
# Out:
# count    2051.000000
# mean       36.066797
# std        30.211061
# min        -1.000000
# 25%         7.000000
# 50%        34.000000
# 75%        54.000000
# max       136.000000
# Name: age, dtype: float64

# %%
# Found one observation which was an anomaly
housing.loc[housing["age"] == -1]

housing = housing.drop(housing.index[1885])

# %%
housing["age"].describe()
# Out:
# count    2050.000000
# mean       36.084878
# std        30.207330
# min         0.000000
# 25%         7.000000
# 50%        34.000000
# 75%        54.000000
# max       136.000000
# Name: age, dtype: float64

# %%
# Calculating the age for the Validation Dataset
valid["age"] = valid["Yr Sold"] - valid["Year Built"]

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2050 entries, 0 to 2050
# Data columns (total 82 columns):
# Id                 2050 non-null int64
# PID                2050 non-null int64
# MS SubClass        2050 non-null object
# MS Zoning          2050 non-null object
# Lot Frontage       1720 non-null float64
# Lot Area           2050 non-null int64
# Street             2050 non-null object
# Alley              140 non-null object
# Lot Shape          2050 non-null object
# Land Contour       2050 non-null object
# Utilities          2050 non-null object
# Lot Config         2050 non-null object
# Land Slope         2050 non-null object
# Neighborhood       2050 non-null object
# Condition 1        2050 non-null object
# Condition 2        2050 non-null object
# Bldg Type          2050 non-null object
# House Style        2050 non-null object
# Overall Qual       2050 non-null int64
# Overall Cond       2050 non-null int64
# Year Built         2050 non-null int64
# ...

# %%
housing["Exter Cond"].unique()
# Out:
# array(['TA', 'Gd', 'Fa', 'Ex', 'Po'], dtype=object)

# %%
housing["Garage Qual"].value_counts()
# Out:
# TA    1831
# Fa      82
# Gd      18
# Ex       3
# Po       2
# Name: Garage Qual, dtype: int64

# %% [markdown]
# ### Drop the irrelevant columns from both datasets

# %% [markdown]
# Reasons for dropping these columns:
# PID : There is already an ID column.
# Lot Frontage: It had a lot of missing values and I didn't think it was an important factor for sale price
# Year Built and Year Sold - I have calculated the age of the house by subtracting one from the other.
# Alley - 93% of the houses did not have an alley.
# Utilities - 100% of the houses had public utilities. A categorical variable was not needed.
# !st Floor SF, 2nd Floor SF, Low Q Fin SF - Have another variable for the living area square footage which is the addition of these.
# Fireplace Qu - had a lot of missing data and I didn't think it was very relevant.
# Electrical - 92% of the population had the same electrical system.
# Garage Cars - Already have a variable called Garage Area that measures the size of the garage.
# Pool Area and Pool QC - Not too many houses have pools.
# Misc Value - These were the misc features in a house. There were not too many of them.
# Fence - Did not seem relevant to house price.
# Garage Year Built - Did not seem relevant.
# Bsmt Fin SF1 and Bsmt Fin SF 2 and Bsmt UF SF - They were combined into feature called total basement SF.
# Bsmt Full Bath and Bsmt Half Bath - Feature engineered into one.
# Mas Vnr Area - did not seem relevant.
# Garage Area - had outliers.
# Sale Type - did not seem relevant.

# %%
housing1 = housing.drop(columns =["PID","Lot Frontage","Year Built","Yr Sold","Alley","Utilities",
                                  "1st Flr SF", "2nd Flr SF","Low Qual Fin SF","Fireplace Qu","Electrical",
                                "3Ssn Porch","Garage Cars","Pool Area","Pool QC","Misc Val", "Fence",
                                  "Garage Yr Blt",'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Full Bath',
                                  'Bsmt Half Bath','Misc Feature','Bsmt Unf SF','Mas Vnr Area',
                                  'Garage Area','Sale Type'])

valid_1 = valid.drop(columns = ["PID","Lot Frontage","Year Built","Yr Sold","Alley","Utilities",
                                  "1st Flr SF", "2nd Flr SF","Low Qual Fin SF","Fireplace Qu","Electrical",
                                "3Ssn Porch","Garage Cars","Pool Area","Pool QC","Misc Val", "Fence",
                                  "Garage Yr Blt",'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Full Bath',
                                  'Bsmt Half Bath','Misc Feature','Bsmt Unf SF','Mas Vnr Area',
                                  'Garage Area','Sale Type'])

# %% [markdown]
# ### Looking at the Categorical Data - Filling the NA category with 'Not'

# %%
ordinals = ["Exter Qual","Exter Cond","Bsmt Qual","Bsmt Cond","Bsmt Exposure","BsmtFin Type 1",
           "BsmtFin Type 2","Garage Qual","Garage Finish","Garage Cond"]



housing1[ordinals] = housing1[ordinals].fillna("Not")
valid_1[ordinals] = valid_1[ordinals].fillna("Not")

# %%
# Removing the nulls.
housing1.fillna(0)
valid_1.fillna(0)
# Out:
#        Id MS SubClass MS Zoning  Lot Area Street Lot Shape Land Contour  \
# 0    2658         190        RM      9142   Pave       Reg          Lvl
# 1    2718          90        RL      9662   Pave       IR1          Lvl
# 2    2414          60        RL     17104   Pave       IR1          Lvl
# 3    1989          30        RM      8520   Pave       Reg          Lvl
# 4     625          20        RL      9500   Pave       IR1          Lvl
# ..    ...         ...       ...       ...    ...       ...          ...
# 873  1662          60        RL      8000   Pave       Reg          Lvl
# 874  1234          60        RL     14670   Pave       Reg          Lvl
# 875  1373          20        RL      8250   Pave       Reg          Lvl
# 876  1672          20        RL      9000   Pave       Reg          Lvl
# 877  1939          20        RL      8400   Pave       Reg          Lvl
#
#     Lot Config Land Slope Neighborhood  ... Garage Finish Garage Qual  \
# ...

# %%
housing1.isnull().sum().sort_values(ascending = False)
# Out:
# Garage Type       113
# Mas Vnr Type       22
# Total Bsmt SF       1
# age                 0
# House Style         0
# Exter Cond          0
# Exter Qual          0
# Exterior 2nd        0
# Exterior 1st        0
# Roof Matl           0
# Roof Style          0
# Year Remod/Add      0
# Overall Cond        0
# Overall Qual        0
# Bldg Type           0
# Bsmt Qual           0
# Condition 2         0
# Condition 1         0
# Neighborhood        0
# Land Slope          0
# Lot Config          0
# Land Contour        0
# Lot Shape           0
# Street              0
# Lot Area            0
# MS Zoning           0
# MS SubClass         0
# Foundation          0
# Bsmt Exposure       0
# Bsmt Cond           0
# SalePrice           0
# Mo Sold             0
# Screen Porch        0
# Enclosed Porch      0
# Open Porch SF       0
# Wood Deck SF        0
# Paved Drive         0
# Garage Cond         0
# Garage Qual         0
# Garage Finish       0
# Fireplaces          0
# ...

# %%
housing1.shape
# Out:
# (2050, 55)

# %%
valid_1.shape
# Out:
# (878, 54)

# %% [markdown]
# ### Making a dictionary for the ordinal variables

# %%
# Making dictionaries for ordinal columns

gen_qual = {
    "Not":0,
    "Po":1,
    "Fa":2,
    "TA":3,
    "Gd":4,
    "Ex":5
}
Lotshape_qual = {
    "IR3" :0,
    "IR2":1,
    "IR1":2,
    "Reg":3
    
}

Landslope_qual = {
    "Sev":0,
    "Mod":1,
    "Gtl":2
}

Bsmtexp_qual = {
    "Not":0,
    "No":1,
    "Mn":2,
    "Av":3,
    "Gd":4
}

BsmtFin_qual = {
    "Not":0,
    "Unf":1,
    "LwQ":2,
    "Rec":3,
    "BLQ":4,
    "ALQ":5,
    "GLQ":6
}

Func_qual = {
    "Sal":0,
    "Sev":1,
    "Maj2":2,
    "Maj1":3,
    "Mod":4,
    "Min2":5,
    "Min1":6,
    "Typ":7
}

Paved_qual = {
    "N":0,
    "P":1,
    "Y":2
}

# %%
housing1["Lot Shape"].head()
# Out:
# 0    IR1
# 1    IR1
# 2    Reg
# 3    Reg
# 4    IR1
# Name: Lot Shape, dtype: object

# %% [markdown]
# ### Applying the dictionary to both the dataframes

# %%
housing1["Lot Shape"] = housing1["Lot Shape"].map(Lotshape_qual)
housing1["Land Slope"] = housing1["Land Slope"].map(Landslope_qual)
housing1["Exter Cond"] = housing1["Exter Cond"].map(gen_qual)
housing1["Exter Qual"] = housing1["Exter Qual"].map(gen_qual)
housing1["Bsmt Qual"] = housing1["Bsmt Qual"].map(gen_qual)
housing1["Bsmt Cond"] = housing1["Bsmt Cond"].map(gen_qual)
housing1["Bsmt Exposure"] = housing1["Bsmt Exposure"].map(Bsmtexp_qual)
housing1["BsmtFin Type 1"] = housing1["BsmtFin Type 1"].map(BsmtFin_qual)
housing1["BsmtFin Type 2"] = housing1["BsmtFin Type 2"].map(BsmtFin_qual)
housing1["Functional"] = housing1["Functional"].map(Func_qual)
housing1["Garage Qual"] = housing1["Garage Qual"].map(gen_qual)
housing1["Garage Cond"] = housing1["Garage Cond"].map(gen_qual)
housing1["Paved Drive"] = housing1["Paved Drive"].map(Paved_qual)

# %%
valid_1["Lot Shape"] = valid_1["Lot Shape"].map(Lotshape_qual)
valid_1["Land Slope"] = valid_1["Land Slope"].map(Landslope_qual)  
valid_1["Exter Cond"] = valid_1["Exter Cond"].map(gen_qual) 
valid_1["Exter Qual"] = valid_1["Exter Qual"].map(gen_qual)
valid_1["Bsmt Qual"] = valid_1["Bsmt Qual"].map(gen_qual)
valid_1["Bsmt Cond"] = valid_1["Bsmt Cond"].map(gen_qual)
valid_1["Bsmt Exposure"] = valid_1["Bsmt Exposure"].map(Bsmtexp_qual)
valid_1["BsmtFin Type 1"] = valid_1["BsmtFin Type 1"].map(BsmtFin_qual)
valid_1["BsmtFin Type 2"] = valid_1["BsmtFin Type 2"].map(BsmtFin_qual)
valid_1["Functional"] = valid_1["Functional"].map(Func_qual)
valid_1["Garage Qual"] = valid_1["Garage Qual"].map(gen_qual)
valid_1["Garage Cond"] = valid_1["Garage Cond"].map(gen_qual)
valid_1["Paved Drive"] = valid_1["Paved Drive"].map(Paved_qual)

# %%
housing1["Land Slope"].sort_values(ascending = False)
# Out:
# 2050    2
# 708     2
# 693     2
# 695     2
# 697     2
#        ..
# 9       0
# 694     0
# 745     0
# 108     0
# 1372    0
# Name: Land Slope, Length: 2050, dtype: int64

# %%
valid_1["Land Slope"].sort_values(ascending = False)
# Out:
# 877    2
# 308    2
# 305    2
# 304    2
# 303    2
#       ..
# 23     0
# 213    0
# 842    0
# 445    0
# 306    0
# Name: Land Slope, Length: 878, dtype: int64

# %%
housing1.shape
# Out:
# (2050, 55)

# %%
valid_1.shape
# Out:
# (878, 54)

# %%
housing1.columns
# Out:
# Index(['Id', 'MS SubClass', 'MS Zoning', 'Lot Area', 'Street', 'Lot Shape',
#        'Land Contour', 'Lot Config', 'Land Slope', 'Neighborhood',
#        'Condition 1', 'Condition 2', 'Bldg Type', 'House Style',
#        'Overall Qual', 'Overall Cond', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond',
#        'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Gr Liv Area', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Garage Type',
#        'Garage Finish', 'Garage Qual', 'Garage Cond', 'Paved Drive',
#        'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', 'Screen Porch',
#        'Mo Sold', 'SalePrice', 'age'],
#       dtype='object')

# %%
valid_1.columns
# Out:
# Index(['Id', 'MS SubClass', 'MS Zoning', 'Lot Area', 'Street', 'Lot Shape',
#        'Land Contour', 'Lot Config', 'Land Slope', 'Neighborhood',
#        'Condition 1', 'Condition 2', 'Bldg Type', 'House Style',
#        'Overall Qual', 'Overall Cond', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond',
#        'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Gr Liv Area', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Garage Type',
#        'Garage Finish', 'Garage Qual', 'Garage Cond', 'Paved Drive',
#        'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', 'Screen Porch',
#        'Mo Sold', 'age'],
#       dtype='object')

# %%
housing1.head()
# Out:
#     Id MS SubClass MS Zoning  Lot Area Street  Lot Shape Land Contour  \
# 0  109          60        RL     13517   Pave          2          Lvl
# 1  544          60        RL     11492   Pave          2          Lvl
# 2  153          20        RL      7922   Pave          3          Lvl
# 3  318          60        RL      9802   Pave          3          Lvl
# 4  255          50        RL     14235   Pave          2          Lvl
#
#   Lot Config  Land Slope Neighborhood  ... Garage Qual Garage Cond  \
# 0    CulDSac           2       Sawyer  ...           3           3
# 1    CulDSac           2      SawyerW  ...           3           3
# 2     Inside           2        NAmes  ...           3           3
# 3     Inside           2       Timber  ...           3           3
# 4     Inside           2      SawyerW  ...           3           3
#
#   Paved Drive Wood Deck SF  Open Porch SF  Enclosed Porch  Screen Porch  \
# ...

# %%
valid_1.head()
# Out:
#      Id MS SubClass MS Zoning  Lot Area Street  Lot Shape Land Contour  \
# 0  2658         190        RM      9142   Pave          3          Lvl
# 1  2718          90        RL      9662   Pave          2          Lvl
# 2  2414          60        RL     17104   Pave          2          Lvl
# 3  1989          30        RM      8520   Pave          3          Lvl
# 4   625          20        RL      9500   Pave          2          Lvl
#
#   Lot Config  Land Slope Neighborhood  ... Garage Finish Garage Qual  \
# 0     Inside           2      OldTown  ...           Unf           1
# 1     Inside           2       Sawyer  ...           Fin           3
# 2     Inside           2      Gilbert  ...           RFn           3
# 3     Inside           2      OldTown  ...           Unf           2
# 4     Inside           2        NAmes  ...           RFn           3
#
#   Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  \
# ...

# %%
housing1.fillna(0)
# Out:
#         Id MS SubClass MS Zoning  Lot Area Street  Lot Shape Land Contour  \
# 0      109          60        RL     13517   Pave          2          Lvl
# 1      544          60        RL     11492   Pave          2          Lvl
# 2      153          20        RL      7922   Pave          3          Lvl
# 3      318          60        RL      9802   Pave          3          Lvl
# 4      255          50        RL     14235   Pave          2          Lvl
# ...    ...         ...       ...       ...    ...        ...          ...
# 2046  1587          20        RL     11449   Pave          2          HLS
# 2047   785          30        RL     12342   Pave          2          Lvl
# 2048   916          50        RL      7558   Pave          3          Bnk
# 2049   639          20        RL     10400   Pave          3          Lvl
# 2050    10          60        RL      7500   Pave          3          Lvl
#
#      Lot Config  Land Slope Neighborhood  ... Garage Qual Garage Cond  \
# ...

# %%
valid_1.fillna(0)
# Out:
#        Id MS SubClass MS Zoning  Lot Area Street  Lot Shape Land Contour  \
# 0    2658         190        RM      9142   Pave          3          Lvl
# 1    2718          90        RL      9662   Pave          2          Lvl
# 2    2414          60        RL     17104   Pave          2          Lvl
# 3    1989          30        RM      8520   Pave          3          Lvl
# 4     625          20        RL      9500   Pave          2          Lvl
# ..    ...         ...       ...       ...    ...        ...          ...
# 873  1662          60        RL      8000   Pave          3          Lvl
# 874  1234          60        RL     14670   Pave          3          Lvl
# 875  1373          20        RL      8250   Pave          3          Lvl
# 876  1672          20        RL      9000   Pave          3          Lvl
# 877  1939          20        RL      8400   Pave          3          Lvl
#
#     Lot Config  Land Slope Neighborhood  ... Garage Finish Garage Qual  \
# ...

# %%
valid_1.shape
# Out:
# (878, 54)

# %%
housing1.shape
# Out:
# (2050, 55)

# %% [markdown]
# ## Combining both dataframes to create dummy variables for both

# %%
combination = pd.concat([housing1, valid_1])
combination.shape
# Out:
# /anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# (2928, 55)

# %%
combination.head()
# Out:
#    Bedroom AbvGr Bldg Type  Bsmt Cond  Bsmt Exposure  Bsmt Qual  \
# 0              3      1Fam          3              1          3
# 1              4      1Fam          3              1          4
# 2              3      1Fam          3              1          3
# 3              3      1Fam          3              1          4
# 4              3      1Fam          4              1          2
#
#    BsmtFin Type 1  BsmtFin Type 2 Central Air Condition 1 Condition 2  ...  \
# 0               6               1           Y        RRAe        Norm  ...
# 1               6               1           Y        Norm        Norm  ...
# 2               6               1           Y        Norm        Norm  ...
# 3               1               1           Y        Norm        Norm  ...
# 4               1               1           Y        Norm        Norm  ...
#
#    Roof Matl  Roof Style  SalePrice Screen Porch Street  TotRms AbvGrd  \
# ...

# %%
#Creating the dummies for all the nominal variables
combination = pd.get_dummies(data = combination, columns = ['MS SubClass', 'MS Zoning','Street',
       'Land Contour', 'Lot Config', 'Neighborhood',
       'Condition 1', 'Condition 2', 'Bldg Type', 'House Style',
       'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd',
       'Mas Vnr Type','Foundation','Central Air',
       'Garage Type'], drop_first = True)

# %%
combination.shape
# Out:
# (2928, 177)

# %%
housing2 = combination.head(2050)

# %%
housing2.shape
# Out:
# (2050, 177)

# %%
valid_2 = combination.tail(combination.shape[0] - 2050)

# %%
valid_2.shape
# Out:
# (878, 177)

# %%
valid_2 = valid_2.drop(columns = ["SalePrice"])

# %%
valid_2.shape
# Out:
# (878, 176)

# %%
housing2["Total Bsmt SF"] = housing2["Total Bsmt SF"].fillna(0)
# Out:
# /anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
housing2.head()
# Out:
#    Bedroom AbvGr  Bsmt Cond  Bsmt Exposure  Bsmt Qual  BsmtFin Type 1  \
# 0              3          3              1          3               6
# 1              4          3              1          4               6
# 2              3          3              1          3               6
# 3              3          3              1          4               1
# 4              3          4              1          2               1
#
#    BsmtFin Type 2  Enclosed Porch  Exter Cond  Exter Qual  Fireplaces  ...  \
# 0               1               0           3           4           0  ...
# 1               1               0           3           4           1  ...
# 2               1               0           4           3           0  ...
# 3               1               0           3           3           0  ...
# 4               1               0           3           3           0  ...
#
#    Foundation_PConc  Foundation_Slab  Foundation_Stone Foundation_Wood  \
# ...

# %%
valid_2.head()
# Out:
#    Bedroom AbvGr  Bsmt Cond  Bsmt Exposure  Bsmt Qual  BsmtFin Type 1  \
# 0              4          3              1          2               1
# 1              6          3              1          4               1
# 2              3          4              3          4               6
# 3              2          3              1          3               1
# 4              3          3              1          4               4
#
#    BsmtFin Type 2  Enclosed Porch  Exter Cond  Exter Qual  Fireplaces  ...  \
# 0               1             112           2           3           0  ...
# 1               1               0           3           3           0  ...
# 2               1               0           3           4           1  ...
# 3               1             184           3           4           0  ...
# 4               1               0           3           3           2  ...
#
#    Foundation_PConc  Foundation_Slab  Foundation_Stone Foundation_Wood  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
housing_num = housing2._get_numeric_data()
valid_num = valid_2._get_numeric_data()

# %%
housing_num.head()
# Out:
#    Bedroom AbvGr  Bsmt Cond  Bsmt Exposure  Bsmt Qual  BsmtFin Type 1  \
# 0              3          3              1          3               6
# 1              4          3              1          4               6
# 2              3          3              1          3               6
# 3              3          3              1          4               1
# 4              3          4              1          2               1
#
#    BsmtFin Type 2  Enclosed Porch  Exter Cond  Exter Qual  Fireplaces  ...  \
# 0               1               0           3           4           0  ...
# 1               1               0           3           4           1  ...
# 2               1               0           4           3           0  ...
# 3               1               0           3           3           0  ...
# 4               1               0           3           3           0  ...
#
#    Foundation_PConc  Foundation_Slab  Foundation_Stone  Foundation_Wood  \
# ...

# %%
valid_num.head()
# Out:
#    Bedroom AbvGr  Bsmt Cond  Bsmt Exposure  Bsmt Qual  BsmtFin Type 1  \
# 0              4          3              1          2               1
# 1              6          3              1          4               1
# 2              3          4              3          4               6
# 3              2          3              1          3               1
# 4              3          3              1          4               4
#
#    BsmtFin Type 2  Enclosed Porch  Exter Cond  Exter Qual  Fireplaces  ...  \
# 0               1             112           2           3           0  ...
# 1               1               0           3           3           0  ...
# 2               1               0           3           4           1  ...
# 3               1             184           3           4           0  ...
# 4               1               0           3           3           2  ...
#
#    Foundation_PConc  Foundation_Slab  Foundation_Stone  Foundation_Wood  \
# ...

# %% [markdown]
# ### Some Feature Engineering

# %%
# Creating 3 new features. Am doing it here so that I can use them for visualizations.
# overall_quality  = Overall Quality * Overall Cond 
#        This variable is an indicator of the overall quality of the house
# Total Baths = Full Baths * (0.5) * Half Baths 
#        This variable gives half baths a weight of half.
# Total SF = Ground Living Area + Total Basement SF
#        This variable calculates the total square footage of the house

# %%
#housing_num["overall_qual"] = housing_num["Overall Qual"] * housing_num["Overall Cond"]
housing_num["Total Baths"] = housing_num["Full Bath"] + (0.5 * housing_num["Half Bath"])
housing_num["Total SF"] = housing_num["Gr Liv Area"] + housing_num["Total Bsmt SF"]
housing_num = housing_num.drop(columns = ["Gr Liv Area","Total Bsmt SF"])

# %% [markdown]
# ### Visualizations

# %%
plt.figure(figsize=(16,9))

corr = housing_num.corr()[['SalePrice']].sort_values('SalePrice', ascending = False)
mask1=abs(corr['SalePrice'])> 0.4
ax = sns.heatmap(corr[mask1],cmap = 'coolwarm', annot=True)
sns.set(font_scale = 2)
ax.set_title("Correlation matrix of features with Sale Price");

# %%
housing1.corr()["SalePrice"].sort_values(ascending = False)
# Out:
# SalePrice         1.000000
# Overall Qual      0.801622
# Exter Qual        0.713387
# Gr Liv Area       0.705882
# Total Bsmt SF     0.641562
# Bsmt Qual         0.612583
# Year Remod/Add    0.550539
# Full Bath         0.538036
# TotRms AbvGrd     0.507680
# Fireplaces        0.471621
# Bsmt Exposure     0.425332
# BsmtFin Type 1    0.350457
# Open Porch SF     0.336914
# Wood Deck SF      0.327428
# Lot Area          0.297871
# Paved Drive       0.290475
# Garage Qual       0.285282
# Half Bath         0.283091
# Garage Cond       0.265022
# Bsmt Cond         0.225074
# Bedroom AbvGr     0.137117
# Screen Porch      0.134588
# Functional        0.125680
# Exter Cond        0.036422
# Mo Sold           0.032730
# BsmtFin Type 2    0.014075
# Id               -0.051419
# Land Slope       -0.057994
# Overall Cond     -0.097018
# Kitchen AbvGr    -0.125442
# Enclosed Porch   -0.135656
# Lot Shape        -0.294606
# age              -0.572074
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize = (16,6))
ax = sns.boxplot( x = housing1["Mo Sold"], y= housing1["SalePrice"])
ax.set_title("Relationship between the Month Sold and Sale Price");

# %%
plt.figure(figsize = (16,6))
ax =sns.boxplot( x = housing1["Neighborhood"], y= housing1["SalePrice"])
ax.set_title("Relationship between House Prices and Neighborhoods", fontsize = 20)
sns.set(font_scale = 1)
ax.set_xticklabels(ax.get_xticklabels(), rotation=30);

# %%
plt.figure(figsize = (16,10))
ax = sns.scatterplot(x=housing1["age"], y = housing1["SalePrice"])
sns.set(font_scale = 2)
ax.set_title("Relationship between SalePrice and the age of the house");

# %%
plt.figure(figsize = (16,6))
ax = sns.scatterplot(x=housing1["Year Remod/Add"], y = housing1["SalePrice"])
sns.set(font_scale = 2)
ax.set_title("Relationship between SalePrice and when the house was Remodeled");

# %%
plt.figure(figsize = (16,6))
ax = sns.boxplot(x=housing_num["Overall Qual"], y = housing_num["SalePrice"])
sns.set(font_scale = 2)
ax.set_title("Overall Quality of the house v/s Sales Price", fontsize = 18);

# %%
sns.scatterplot(x=housing_num["Overall Qual"], y = housing_num["SalePrice"]);

# %%
plt.figure(figsize =(12,10))
sns.set(font_scale = 2)
ax = sns.scatterplot(x=housing_num["Total SF"], y = housing_num["SalePrice"])
ax.set_title("Living Area V/s the Sales Price", fontsize = 20);

# %%
plt.figure(figsize = (12,8))
ax = sns.distplot(housing1["SalePrice"])
ax.set_title("Frequency plot of the target variable, Sales Price");

# %%
plt.figure(figsize = (12,8))
ax = sns.distplot(housing1["age"])
ax.set_title("Frequency plot of the age of houses");

# %%
plt.figure(figsize = (10,8))
ax = sns.scatterplot(x =housing_num["Total SF"],y = housing1["SalePrice"])
ax.set_title('Impact of Square Feet on SalePrice', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Impact of Square Feet on SalePrice')

# %%
housing_num["SalePrice"].describe()
# Out:
# count      2050.000000
# mean     181468.540488
# std       79277.980360
# min       12789.000000
# 25%      129812.500000
# 50%      162500.000000
# 75%      214000.000000
# max      611657.000000
# Name: SalePrice, dtype: float64

# %%
housing_num.shape
# Out:
# (2050, 173)

# %%
valid_num.shape
# Out:
# (878, 172)

# %%
housing_num.columns
# Out:
# Index(['Bedroom AbvGr', 'Bsmt Cond', 'Bsmt Exposure', 'Bsmt Qual',
#        'BsmtFin Type 1', 'BsmtFin Type 2', 'Enclosed Porch', 'Exter Cond',
#        'Exter Qual', 'Fireplaces',
#        ...
#        'Foundation_Stone', 'Foundation_Wood', 'Central Air_Y',
#        'Garage Type_Attchd', 'Garage Type_Basment', 'Garage Type_BuiltIn',
#        'Garage Type_CarPort', 'Garage Type_Detchd', 'Total Baths', 'Total SF'],
#       dtype='object', length=173)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Baseline Model

# %%
target = "SalePrice"
X = housing_num.drop(columns = target)
y = housing_num[target]

# %%
y_bar = y - np.mean(y)
y_bar
# Out:
# 0       -50968.540488
# 1        38531.459512
# 2       -72468.540488
# 3        -7468.540488
# 4       -42968.540488
#             ...
# 2046    117282.459512
# 2047    -98968.540488
# 2048     -4468.540488
# 2049    -37468.540488
# 2050      7531.459512
# Name: SalePrice, Length: 2050, dtype: float64

# %%
# Finding baseline RMSE using the mean of Y

resid_mean = y - np.mean(y)
mse_base = np.mean(resid_mean ** 2)
rmse_base = np.sqrt(mse_base)
rmse_base
# Out:
# 79258.64190844606

# %% [markdown]
# ## Linear Regression Model

# %% [markdown]
# ### Model 1 - Using the entire dataset

# %%
target = "SalePrice"
X = housing_num.drop(columns = target)
y = housing_num[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 250)

# %%
X_train.shape
# Out:
# (1537, 172)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.score(X_train,y_train)
# Out:
# 0.9158683261862558

# %%
lr.score(X_test, y_test)
# Out:
# 0.8867252799812488

# %%
cross_val_score(lr, X, y, cv = 5).mean()
# Out:
# 0.8621385831537627

# %%
list(zip(lr.coef_,X.columns))
# Out:
# [(-8024.64419325188, 'Bedroom AbvGr'),
#  (-7758.879825101947, 'Bsmt Cond'),
#  (4278.944132323407, 'Bsmt Exposure'),
#  (1695.0743153690576, 'Bsmt Qual'),
#  (2925.561182825313, 'BsmtFin Type 1'),
#  (280.8835186058648, 'BsmtFin Type 2'),
#  (14.763554326560325, 'Enclosed Porch'),
#  (-443.3523283467453, 'Exter Cond'),
#  (10681.25672384005, 'Exter Qual'),
#  (3539.084363090081, 'Fireplaces'),
#  (1176.5582687733229, 'Full Bath'),
#  (5841.3952156390515, 'Functional'),
#  (-2033.8425006962452, 'Garage Cond'),
#  (3326.9378568115967, 'Garage Qual'),
#  (6015.606175296883, 'Half Bath'),
#  (0.22283800880711624, 'Id'),
#  (-17819.56585961908, 'Kitchen AbvGr'),
#  (3782.097039573697, 'Land Slope'),
#  (0.8393148824588934, 'Lot Area'),
#  (1796.8759730147751, 'Lot Shape'),
#  (67.14143591961044, 'Mo Sold'),
#  (13.962181140789653, 'Open Porch SF'),
#  (4636.093917840945, 'Overall Cond'),
#  (8106.341405913046, 'Overall Qual'),
#  (1737.2574113808669, 'Paved Drive'),
# ...

# %%
yhat_train = lr.predict(X_train) 
yhat_test = lr.predict(X_test)

# %%
def plot_predictions(model_name, y_train_pred, y_test_pred, y_train_actual, y_test_actual):
    plt.scatter(y_train_pred, y_train_actual, c = "blue", marker = "s", label = "Training data")
    plt.scatter(y_test_pred, y_test_actual, c = "lightgreen", marker = "s", label = "Testing data")
    plt.title(model_name+"Regression", fontsize = 24)
    plt.xlabel(("$\hat{y}$ = Predicted SalePrice"),fontsize = 24)
    plt.ylabel(("$y$ = Actual SalePrice"), fontsize = 24)
    plt.legend(loc = "upper left")
    plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], c='red')
    plt.tight_layout()

# %%
plt.figure(figsize =(16,9))
plot_predictions(model_name = "Linear ",
                 y_train_pred = yhat_train,
                 y_test_pred = yhat_test,
                 y_train_actual = y_train,
                 y_test_actual = y_test)

# %%
resids = y_test - yhat_test
resids.mean()
# Out:
# -216.6613783802475

# %%
resids.min()
# Out:
# -168380.54021421773

# %%
resids[resids == resids.min()]
# Out:
# 125   -168380.540214
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize = (16,9))
plt.scatter(range(len(resids)), resids)
plt.axhline(0, color='r')
plt.title("ScatterPlot of Errors", fontsize = 28)
# Out:
# Text(0.5, 1.0, 'ScatterPlot of Errors')

# %% [markdown]
# ### Finding RMSE Scores

# %%
target = "SalePrice"
X = housing_num.drop(columns = target)
y = housing_num[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 250)

# %%
# Finding baseline RMSE using the mean of Y

resid_mean = y - np.mean(y)
mse_base = np.mean(resid_mean ** 2)
rmse_base = np.sqrt(mse_base)
rmse_base
# Out:
# 79258.64190844606

# %%
resid_test = y_test - yhat_test
mse_test = np.mean(resid_test ** 2)
rmse_test = np.sqrt(mse_test)
rmse_test
# Out:
# 26747.824698750894

# %%
resid_train = y_train - yhat_train
mse_train = np.mean(resid_train ** 2)
rmse_train = np.sqrt(mse_train)
rmse_train
# Out:
# 22968.360478211627

# %% [markdown]
# My RMSE is 22967.006 for the Training data and 26836.59 for the Testing data with this model which is a big improvement from the baseline model.

# %%
def rmse(y_true, y_pred): # this signature matters for later use with `make_scorer`
    '''Returns the root mean squared error'''
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
from sklearn.metrics import mean_squared_error, make_scorer
cross_val_score(lr, X, y, cv = 5, scoring = make_scorer(rmse)).mean()
# Out:
# 29132.691259419335

# %% [markdown]
# ## Running the model on the Validation dataset

# %%
valid_num["Total Baths"] = housing_num["Full Bath"] + (0.5 * housing_num["Half Bath"])
valid_num["Total SF"] = valid_num["Gr Liv Area"] + valid_num["Total Bsmt SF"]
valid_num = valid_num.drop(columns =["Gr Liv Area","Total Bsmt SF"])

# %%
preds = lr.predict(valid_num)

# %%
preds_col = pd.Series(preds, name = "SalePrice")
id_col = valid_num["Id"]
#Combine the two into one dataset

output = pd.concat([id_col, preds_col], axis = 1)
output.head()
# Out:
#      Id      SalePrice
# 0  2658  149589.527536
# 1  2718  165823.839662
# 2  2414  197179.653814
# 3  1989  121090.599788
# 4   625  178122.115147

# %% [markdown]
# ### Submitting to Kaggle

# %%
output.to_csv("./output/submission5.csv", index = False)

# %% [markdown]
# # Model 2 - Trying different features

# %%
target = "SalePrice"
features = ["age","Exter Qual","Overall Qual","TotRms AbvGrd","Year Remod/Add","Total Baths",
           "Total SF"]
X_1 = housing_num[features]
y_1 = housing_num[target]

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X_1,y_1, random_state=42)
linreg = LinearRegression()
linreg.fit(X1_train,y1_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linreg.score(X1_train,y1_train)
# Out:
# 0.790838627267163

# %%
linreg.score(X1_test, y1_test)
# Out:
# 0.8257282562490196

# %%
linreg.coef_
# Out:
# array([ -279.92379116, 25801.55166004, 16325.48494508,  4857.75091465,
#          170.44726743, -4484.85606354,    38.58103834])

# %%
linreg.intercept_
# Out:
# -455908.2650141001

# %% [markdown]
# # Model 3 - Looking at the variance in price explained by the two most correlated variables - Total Area and Overall Quality of the house

# %%
target = "SalePrice"
features = ["Total SF", "Overall Qual"]
X_2 = housing_num[features]
y_2 = housing_num[target]

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X_2,y_2, random_state=42)
linreg = LinearRegression()
linreg.fit(X2_train,y2_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linreg.score(X2_train,y2_train)
# Out:
# 0.754520522355106

# %%
linreg.score(X2_test, y2_test)
# Out:
# 0.816518675215796

# %%
linreg.score(X_2,y_2)
# Out:
# 0.7703080904941707

# %%
cross_val_score(linreg, X, y, cv = 5).mean()
# Out:
# 0.8621385831537627

# %% [markdown]
# # Lasso Regression

# %%
target = "SalePrice"
X = housing_num.drop(columns=target)
y = housing_num[target]

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = RANDOM_STATE)

# Scale data
ss = StandardScaler()
X_train_ss = ss.fit_transform(X_train)
X_test_ss  = ss.transform(X_test)

# %%
l_alphas = np.logspace(-2,0, 100)
lasso = LassoCV(alphas = l_alphas, cv = 5, random_state = RANDOM_STATE)

lasso.fit(X_train_ss, y_train)
# Out:
# /anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233906729284.43817, tolerance: 829650928.364267
#   tol, rng, random, positive)
# /anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130643762815.43903, tolerance: 829650928.364267
#   tol, rng, random, positive)
# /anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101374646525.98523, tolerance: 829650928.364267
#   tol, rng, random, positive)
# ...

# %%
def rmse(y_true, y_pred): # this signature matters for later use with `make_scorer`
    '''Returns the root mean squared error'''
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
# train score
train_preds = lasso.predict(X_train_ss)
rmse(y_train, train_preds)
# Out:
# 23760.283678865395

# %%
# test score
test_preds = lasso.predict(X_test_ss)
rmse(y_test, test_preds)
# Out:
# 34596.38501690419

# %%
from sklearn.metrics import make_scorer
# cross_val score
cross_val_score(lasso, X, y, cv = 5, scoring = make_scorer(rmse)).mean()
# Out:
# /anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 343828728811.15216, tolerance: 824338670.5662388
#   tol, rng, random, positive)
# /anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 343504274560.61865, tolerance: 824338670.5662388
#   tol, rng, random, positive)
# /anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 343198240699.0885, tolerance: 824338670.5662388
#   tol, rng, random, positive)
# ...

# %%
list(zip(lasso.coef_,X.columns))
# Out:
# [(-6601.610027845427, 'Bedroom AbvGr'),
#  (-4217.434638765768, 'Bsmt Cond'),
#  (5856.0445167343805, 'Bsmt Exposure'),
#  (1409.8308549241028, 'Bsmt Qual'),
#  (5476.697608720479, 'BsmtFin Type 1'),
#  (439.05693035288806, 'BsmtFin Type 2'),
#  (811.1977819858361, 'Enclosed Porch'),
#  (-99.80500050596119, 'Exter Cond'),
#  (8310.642300149502, 'Exter Qual'),
#  (2514.5907769732335, 'Fireplaces'),
#  (20231.92840532639, 'Full Bath'),
#  (4069.432039825649, 'Functional'),
#  (-2647.615554373836, 'Garage Cond'),
#  (3355.115664666978, 'Garage Qual'),
#  (12786.690117460794, 'Half Bath'),
#  (414.05881908122166, 'Id'),
#  (-2454.2391574068574, 'Kitchen AbvGr'),
#  (193.31482935866066, 'Land Slope'),
#  (5020.603622970486, 'Lot Area'),
#  (390.14142329759716, 'Lot Shape'),
#  (-214.14891586753993, 'Mo Sold'),
#  (1262.9705884624625, 'Open Porch SF'),
#  (6199.839630983621, 'Overall Cond'),
#  (11994.021145341667, 'Overall Qual'),
#  (1029.9222935883622, 'Paved Drive'),
# ...

# %% [markdown]
# ## Trying OLS using statsmodels

# %%
X.shape
# Out:
# (2050, 172)

# %%
y.shape
# Out:
# (2050,)

# %%
import statsmodels.api as sm

target = "SalePrice"
X = housing_num.drop(columns = target)
y = housing_num[target]
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 250)

X["intercept"] =1
model_test = sm.OLS(y_test, X_test).fit()
predictions = model_test.predict(X_test) # make the predictions by the model

# Print out the statistics
print(model_test.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                     40.22
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):          1.56e-163
# Time:                        16:40:38   Log-Likelihood:                -5793.4
# No. Observations:                 513   AIC:                         1.188e+04
# Df Residuals:                     368   BIC:                         1.249e+04
# Df Model:                         144
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Bedroom AbvGr        -2792.1467   2370.022     -1.178      0.240   -7452.632    1868.338
# ...

# %%
sns.scatterplot(x = predictions, y = y)

# %% [markdown]
# # Ridge Regression Model

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42)

# %%
sc = StandardScaler()
scaled_X_train = sc.fit_transform(X_train)
scaled_X_test = sc.transform(X_test)

# %%
r_alphas = np.logspace(-1,2, 100)
ridge_model = RidgeCV(alphas = r_alphas, cv = 5)

# Fit model using overfit data!
ridge_ols = ridge_model.fit(scaled_X_train, y_train)

# %%
def get_CV_score(X, y):
    return cross_val_score(LinearRegression(), X, y, cv = 5).mean()

# %%
print("          Original score using 3 features:", get_CV_score(X, y))
print("Training score using Ridge regularization:", ridge_model.score(scaled_X_train, y_train))
print(" Testing score using Ridge regularization:", ridge_model.score(scaled_X_test, y_test))
# Out:
#           Original score using 3 features: 0.862138583153747
# Training score using Ridge regularization: 0.8976634344608198
#  Testing score using Ridge regularization: 0.8894711819566334

# %%
ridge_model.coef_
# Out:
# array([-2.22522301e+03, -3.07443766e+03,  6.56446521e+03,  2.85703123e+03,
#         5.53303772e+03,  7.40355587e+02, -1.72142146e+01, -4.03489110e+01,
#         8.33256885e+03,  4.41115341e+03,  2.37735667e+03,  1.78526149e+03,
#        -7.33915513e+02,  2.92914061e+03,  3.91861284e+03,  4.81069745e+02,
#        -2.35649755e+03, -1.03327237e+03,  4.66161268e+03,  1.54349230e+03,
#         3.15709265e+02,  1.24646218e+03,  4.27000768e+03,  1.27611593e+04,
#         8.48552581e+02,  4.43580043e+03,  7.82729894e+03,  2.21196249e+03,
#         3.00986249e+03, -4.48412439e+03, -1.48966078e+03, -8.64516212e+02,
#         2.14222909e+02, -9.62980860e+02,  4.39083109e+03,  2.14920289e+03,
#        -2.95283982e+01,  2.77591548e+02,  1.75561791e+03,  7.72750528e+02,
#         1.67264736e+03,  1.18478675e+03, -5.49506327e+02, -1.97502655e+02,
#         2.17429112e+02, -1.01629562e+03,  1.78462323e+03,  0.00000000e+00,
# ...

# %%
y_train_ridge = ridge_model.predict(scaled_X_train)

# %%
y_train_ridge
# Out:
# array([201757.1636057 , 131048.85011894, 160080.85974765, ...,
#        168669.77353298,  95179.76958824, 223474.01724653])

# %%
resid_ridge = y_train - y_train_ridge

# %%
mse = np.mean(resid_ridge**2)
rmse = np.sqrt(mse)
    
rmse
# Out:
# 25280.443281973952

# %%
### The Ridge Regression Model is giving a higher RMSE. It does not significantly improve the model.

# %% [markdown]
# # Choosing my model and plotting the residuals

# %% [markdown]
# ### I chose the Linear Regression model because the Lasso or the Ridge regressions did not significantly improve my model. I wanted to have all the features in my model to see how they affect the price of the house.

# %% [markdown]
# ## Visualization of my chosen model

# %%
target = "SalePrice"
X = housing_num.drop(columns = target)
y = housing_num[target]

# %%
# This beautiful visualization function was made by Mahdi Shadkam-Farrokhi
def vizResids(model_title, X, y):
    # For help with multiple figures: https://matplotlib.org/3.1.1/gallery/subplots_axes_and_figures/subplots_demo.html

    # HANDLING DATA
    # train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 250)

    # instatiate model
    lr = LinearRegression()
    # fit model
    lr.fit(X_train, y_train)

    preds = lr.predict(X_test)
    resids = y_test - preds
    target_name = y.name.capitalize()

    # HANDLING SUBPLOTS
    fig, axes = plt.subplots(2, 2, figsize=(12,10)) # 2 row x 2 columns
    fig.suptitle(f"{model_title}: $R^2$ test ={lr.score(X_test, y_test):2.2%}", fontsize = 24, y = 1.05)

    ax_1 = axes[0][0]
    ax_2 = axes[0][1]
    ax_3 = axes[1][0]

    subplot_title_size = 18
    subplot_label_size = 14
    
    # 1ST PLOT - y_true vs. y_pred
    ax_1.set_title("True Values ($y$) vs. Predictions ($\hat{y}$)", fontsize = subplot_title_size, pad = 10)
    maxDist = max(max(preds),max(y)) # maxiumum value used to determin x_lim and y_lim
    minDist = min(min(preds),min(y)) # maxiumum value used to determin x_lim and y_lim
    # 45deg line, signifying prediction == true value
    ax_1.plot((minDist,maxDist),(minDist,maxDist), c = "r", alpha = .9);
    
    sns.scatterplot(ax = ax_1, x = y_test, y = preds, alpha = .9)
    ax_1.set_xlabel("True Values ($y$)", fontsize = subplot_label_size, labelpad = 10)
    ax_1.set_ylabel("Predictions ($\hat{y}$)", fontsize = subplot_label_size, labelpad = 10)

    # 2ND PLOT - residuals
    ax_2.set_title("Residuals", fontsize = subplot_title_size)
    sns.scatterplot(ax = ax_2, x = range(len(resids)),y = resids, alpha = .9)
    ax_2.set_ylabel(target_name, fontsize = subplot_label_size)
    ax_2.axhline(0, c = "r", alpha = .7);

    # 3RD PLOT - residuals histogram
    ax_3.set_title("Histogram of residuals", fontsize = subplot_title_size)
    sns.distplot(resids, ax = ax_3, kde = False);
    ax_3.set_xlabel(target_name, fontsize = subplot_label_size)
    ax_3.set_ylabel("Frequency", fontsize = subplot_label_size)

    plt.tight_layout() # handles most overlaping and spacing issues

# %%
vizResids("Original Lin. Reg.", X, y)

# %% [markdown]
# # Conclusions

# %% [markdown]
# There were some interesting findings from my analysis. As expected, the size of the house and the overall condition of the house had the maximum impact on house prices. These two variables alone accounted for 77% of the variability of the house price. There were some neighborhoods that seemed more desirable and had higher prices. The unexpected findings in my analysis was that the Basement exposure and the Finished basement variable were very significant. Realizing that Ames, Iowa is in tornado country explains that finding. Also the neighborhood of Crawford had a significant coefficient even though its mean house price was rather low.  I would think that that means that is an upcoming neighborhood.
